# %% [markdown]
# # Intro to pytorch

# %%
import torch

# %%
x = torch.empty(5, 3)

# %%
print(x)
# Out:
# tensor([[ 3.9307e-10,  4.5779e-41, -1.0896e-02],
#         [ 3.0914e-41,  3.8087e-34,  4.5779e-41],
#         [ 3.8074e-34,  4.5779e-41,  5.5511e-10],
#         [ 4.5779e-41,  5.4994e-10,  4.5779e-41],
#         [ 3.8070e-34,  4.5779e-41,  3.8070e-34]])
